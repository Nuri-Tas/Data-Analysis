# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/LinkedInLearning/python-scientific-stack-3006561/main/Ch03/03_02/track.csv', parse_dates=['time'], index_col='time')
df.head()
# Out:
#                                lat        lng      height
# time
# 2015-08-20 03:48:07.235  32.519585  35.015021  136.199997
# 2015-08-20 03:48:24.734  32.519606  35.014954  126.599998
# 2015-08-20 03:48:25.660  32.519612  35.014871  123.000000
# 2015-08-20 03:48:26.819  32.519654  35.014824  120.500000
# 2015-08-20 03:48:27.828  32.519689  35.014776  118.900002

# %% [markdown]
# Get the map of the average latitude and longitude values.

# %%
import folium

center = [df.lat.mean(), df.lng.mean()]
m = folium.Map(
    location=center,
    zoom_start=15
)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e2bbd6bba11b00ff01ed142e61e68fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e2bbd6bba11b00ff01ed142e61e68fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_3e2bbd6bba11b00ff01ed142e61e68fb = L.map(
#                 &quot;map_3e2bbd6bba11b00ff01ed142e61e68fb&quot;,
#                 {
#                     center: [32.51219109324327, 35.015832294594645],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ee5c77e90cb81a040c93ce1686a257d2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3e2bbd6bba11b00ff01ed142e61e68fb);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We can also save the view as html to view it later in our browser.

# %%
m.save('track.html')

# %% [markdown]
# We can add a marker with add_to attribute.

# %%
loc = tuple(df.iloc[100][['lat', 'lng']])
marker = folium.Marker(loc)
marker.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e2bbd6bba11b00ff01ed142e61e68fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e2bbd6bba11b00ff01ed142e61e68fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_3e2bbd6bba11b00ff01ed142e61e68fb = L.map(
#                 &quot;map_3e2bbd6bba11b00ff01ed142e61e68fb&quot;,
#                 {
#                     center: [32.51219109324327, 35.015832294594645],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ee5c77e90cb81a040c93ce1686a257d2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3e2bbd6bba11b00ff01ed142e61e68fb);
#
#
#             var marker_b3d7b7e260defcaf7e08a88e61743957 = L.marker(
#                 [32.514813, 35.012367],
#                 {}
#             ).addTo(map_3e2bbd6bba11b00ff01ed142e61e68fb);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Create a circle marker with a popup.

# %%
m = folium.Map(location=center, zoom_start=15)

red_marker = folium.CircleMarker(loc, color='red', popup='Hi there!')
red_marker.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_19ff8456f3d255cae618de7a22415a6c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_19ff8456f3d255cae618de7a22415a6c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_19ff8456f3d255cae618de7a22415a6c = L.map(
#                 &quot;map_19ff8456f3d255cae618de7a22415a6c&quot;,
#                 {
#                     center: [32.51219109324327, 35.015832294594645],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b6cfbcb70f876b6c4dbb5143094270a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_19ff8456f3d255cae618de7a22415a6c);
#
#
#             var circle_marker_e200eebbc97f86c3aab72433ef772055 = L.circleMarker(
#                 [32.514813, 35.012367],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_19ff8456f3d255cae618de7a22415a6c);
#
#
#         var popup_b4447224ac3e9acc12f14d7d55ed01b7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_92b1df1b5267a3ebf0c616881aeb1ff9 = $(`&lt;div id=&quot;html_92b1df1b5267a3ebf0c616881aeb1ff9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hi there!&lt;/div&gt;`)[0];
#             popup_b4447224ac3e9acc12f14d7d55ed01b7.setContent(html_92b1df1b5267a3ebf0c616881aeb1ff9);
#
#
#         circle_marker_e200eebbc97f86c3aab72433ef772055.bindPopup(popup_b4447224ac3e9acc12f14d7d55ed01b7)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Add multiple markers showing the location for each minute.

# %%
def mark(row):
    loc = tuple(row[['lat', 'lng']])
    marker = folium.CircleMarker(location=loc, color='red', radius=5, popup=row.name.strftime('%H:%M'))
    marker.add_to(m)

# %%
m = folium.Map(location=center, zoom_start=15)

min_df = df.resample('min').mean()
min_df.apply(mark, axis=1)
   
m    #don't forget to click on the circles to see the time.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_056262f9bb61555cf6a056ca0f97e080 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_056262f9bb61555cf6a056ca0f97e080&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_056262f9bb61555cf6a056ca0f97e080 = L.map(
#                 &quot;map_056262f9bb61555cf6a056ca0f97e080&quot;,
#                 {
#                     center: [32.51219109324327, 35.015832294594645],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d2caf2aa397e5bf43e88bb2f76dff3e4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_056262f9bb61555cf6a056ca0f97e080);
#
#
#             var circle_marker_cb13a381db981670ecdf8d83ec82f6cf = L.circleMarker(
#                 [32.51948457142857, 35.01457057142857],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_056262f9bb61555cf6a056ca0f97e080);
#
#
#         var popup_a3de6e870bba35610a1ba06e35d5cff5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_fe31f3c91c8b78a2116060028d61b4a4 = $(`&lt;div id=&quot;html_fe31f3c91c8b78a2116060028d61b4a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;03:48&lt;/div&gt;`)[0];
#             popup_a3de6e870bba35610a1ba06e35d5cff5.setContent(html_fe31f3c91c8b78a2116060028d61b4a4);
#
#
#         circle_marker_cb13a381db981670ecdf8d83ec82f6cf.bindPopup(popup_a3de6e870bba35610a1ba06e35d5cff5)
#         ;
#
#
#
#
#             var circle_marker_c7d03ea0df755f89ea747337542aa703 = L.circleMarker(
#                 [32.51897133333333, 35.01431633333333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_056262f9bb61555cf6a056ca0f97e080);
#
#
#         var popup_e1abb3ae2dde1b98f6f5d3219d274b0a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d4a859e62e0fc8aad367100cf8e52c87 = $(`&lt;div id=&quot;html_d4a859e62e0fc8aad367100cf8e52c87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;03:49&lt;/div&gt;`)[0];
#             popup_e1abb3ae2dde1b98f6f5d3219d274b0a.setContent(html_d4a859e62e0fc8aad367100cf8e52c87);
#
#
#         circle_marker_c7d03ea0df755f89ea747337542aa703.bindPopup(popup_e1abb3ae2dde1b98f6f5d3219d274b0a)
#         ;
#
#
#
#
#             var circle_marker_d0ed3ac5c5e68c436bc44d7c740cf4ee = L.circleMarker(
#                 [32.517257826086954, 35.0140552173913],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_056262f9bb61555cf6a056ca0f97e080);
#
#
#         var popup_f45f7c3351e0d1c6265b0d42daca2bf2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_92a1fc864533337ec6e05eaf8c083f88 = $(`&lt;div id=&quot;html_92a1fc864533337ec6e05eaf8c083f88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;03:50&lt;/div&gt;`)[0];
#             popup_f45f7c3351e0d1c6265b0d42daca2bf2.setContent(html_92a1fc864533337ec6e05eaf8c083f88);
#
#
#         circle_marker_d0ed3ac5c5e68c436bc44d7c740cf4ee.bindPopup(popup_f45f7c3351e0d1c6265b0d42daca2bf2)
#         ;
#
#
#
#
#             var circle_marker_8eb5b405b15cc63975e009b1e96de103 = L.circleMarker(
#                 [32.5162645, 35.01386383333333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;,

# %% [markdown]
# # Shapely

# %% [markdown]
# Create a point with Shapely

# %%
from shapely.geometry import Point

pt = Point(2,1)
pt

# %%
pt.x, pt.y
# Out:
# (2.0, 1.0)

# %%
from shapely.geometry import Polygon

poly = Polygon([
    [0, 0],
    [33, 0],
    [33, 35.02],
])

poly

# %%
poly.area
# Out:
# 1250.0

# %%
centroid = poly.centroid
centroid.x, centroid.y
# Out:
# (33.33333333333333, 16.666666666666664)

# %% [markdown]
# Does the polygon intersect the point?

# %%
poly.intersects(pt)
# Out:
# True

# %%
poly.intersects(Point(2,5))
# Out:
# False

# %% [markdown]
# Now, get the point of all lat and lng values per minute in the dataframe.

# %%
min_df = df.resample('min').mean()
min_df['point'] = min_df[['lat', 'lng']].apply(Point, axis=1)

# %%
min_df.sample(5)
# Out:
#                            lat        lng      height  \
# time
# 2015-08-20 03:54:00  32.513381  35.012358   98.233333
# 2015-08-20 04:12:00  32.510804  35.020452   94.650000
# 2015-08-20 04:10:00  32.511305  35.022528  100.628572
# 2015-08-20 03:51:00  32.516264  35.013864  106.653334
# 2015-08-20 03:56:00  32.512374  35.009665   82.606667
#
#                                                           point
# time
# 2015-08-20 03:54:00        POINT (32.5133812 35.01235836666667)
# 2015-08-20 04:12:00        POINT (32.5108035 35.02045192307692)
# 2015-08-20 04:10:00  POINT (32.5113049047619 35.02252776190476)
# 2015-08-20 03:51:00        POINT (32.5162645 35.01386383333333)
# 2015-08-20 03:56:00        POINT (32.51237433333333 35.0096652)

# %% [markdown]
# Draw the polygon bounded by the points in the dataframe

# %%
coord = [[item.x, item.y] for item in min_df.point ]

poly_map = Polygon(coord)
poly_map

# %%
poly_map.intersects(poly)
# Out:
# False

# %% [markdown]
# Find the points on the dataframe that intersects with the first triangle polygon.

# %%
min_df[min_df.point.apply(poly.intersects)]
# Out:
# Empty DataFrame
# Columns: [lat, lng, height, point]
# Index: []

# %% [markdown]
# Find the coordinates of the exterior of the poly_map.

# %%
poly_map.exterior

# %%
poly_map.exterior.xy
# Out:
# (array('d', [32.51948457142857, 32.51897133333333, 32.517257826086954, 32.5162645, 32.51514063333333, 32.514047375000004, 32.5133812, 32.51279553571429, 32.512374333333334, 32.51132666666667, 32.51088076470588, 32.510076444444444, 32.509374550000004, 32.50876945833333, 32.508269954545455, 32.508267153846155, 32.508504280000004, 32.5087424, 32.50892967857143, 32.509305636363635, 32.50986557142857, 32.510734, 32.5113049047619, 32.51121220833333, 32.5108035, 32.511280166666666, 32.51188715, 32.51250347368421, 32.51318756521739, 32.51392023076923, 32.51476676923077, 32.516021464285714, 32.51687552631579, 32.51948457142857]),
#  array('d', [35.01457057142857, 35.01431633333333, 35.0140552173913, 35.01386383333333, 35.012744399999995, 35.0132405625, 35.01235836666667, 35.01081096428571, 35.0096652, 35.00973111111111, 35.01074235294118, 35.01109733333333, 35.011514950000006, 35.01246870833334, 35.013637045454544, 35.01498384615385, 35.01648572, 35.01796292, 35.01950267857143, 35.02088495454546, 35.02153895238095, 35.02175772727273, 35.02252776190476, 35.02164008333333, 35.02045192307692, 35.01910566666667, 35.0180358, 35.0171572631579, 35.017025347826085, 35.016963076923076, 35.01607546153846, 35.01577553571428, 35.01468457894737, 35.01457057142857]))

# %% [markdown]
# We have two arrays each for x and y coordinates each. Get x and y coordinates together for each point.

# %%
points = np.stack(poly_map.exterior.xy).T
points
# Out:
# array([[32.51948457, 35.01457057],
#        [32.51897133, 35.01431633],
#        [32.51725783, 35.01405522],
#        [32.5162645 , 35.01386383],
#        [32.51514063, 35.0127444 ],
#        [32.51404738, 35.01324056],
#        [32.5133812 , 35.01235837],
#        [32.51279554, 35.01081096],
#        [32.51237433, 35.0096652 ],
#        [32.51132667, 35.00973111],
#        [32.51088076, 35.01074235],
#        [32.51007644, 35.01109733],
#        [32.50937455, 35.01151495],
#        [32.50876946, 35.01246871],
#        [32.50826995, 35.01363705],
#        [32.50826715, 35.01498385],
#        [32.50850428, 35.01648572],
#        [32.5087424 , 35.01796292],
#        [32.50892968, 35.01950268],
#        [32.50930564, 35.02088495],
#        [32.50986557, 35.02153895],
#        [32.510734  , 35.02175773],
#        [32.5113049 , 35.02252776],
#        [32.51121221, 35.02164008],
#        [32.5108035 , 35.02045192],
#        [32.51128017, 35.01910567],
#        [32.51188715, 35.0180358 ],
#        [32.51250347, 35.01715726],
#        [32.51318757, 35.01702535],
#        [32.51392023, 35.01696308],
#        [32.51476677, 35.01607546],
#        [32.51602146, 35.01577554],
#        [32.51687553, 35.01468458],
#        [32.51948457, 35.01457057]])

# %% [markdown]
# Show the exterior polygon on the map.

# %%
m = folium.Map(location=center, zoom_start=15)
m.add_child(folium.PolyLine(points, color='red'))
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_293a536102ae916017d4d5ba33c5e4a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_293a536102ae916017d4d5ba33c5e4a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_293a536102ae916017d4d5ba33c5e4a6 = L.map(
#                 &quot;map_293a536102ae916017d4d5ba33c5e4a6&quot;,
#                 {
#                     center: [32.51219109324327, 35.015832294594645],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e6bd0539d3637ce916c29bcd4685d13 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_293a536102ae916017d4d5ba33c5e4a6);
#
#
#             var poly_line_def2176c98435661d1830bebfbd31a9c = L.polyline(
#                 [[32.51948457142857, 35.01457057142857], [32.51897133333333, 35.01431633333333], [32.517257826086954, 35.0140552173913], [32.5162645, 35.01386383333333], [32.51514063333333, 35.012744399999995], [32.514047375000004, 35.0132405625], [32.5133812, 35.01235836666667], [32.51279553571429, 35.01081096428571], [32.512374333333334, 35.0096652], [32.51132666666667, 35.00973111111111], [32.51088076470588, 35.01074235294118], [32.510076444444444, 35.01109733333333], [32.509374550000004, 35.011514950000006], [32.50876945833333, 35.01246870833334], [32.508269954545455, 35.013637045454544], [32.508267153846155, 35.01498384615385], [32.508504280000004, 35.01648572], [32.5087424, 35.01796292], [32.50892967857143, 35.01950267857143], [32.509305636363635, 35.02088495454546], [32.50986557142857, 35.02153895238095], [32.510734, 35.02175772727273], [32.5113049047619, 35.02252776190476], [32.51121220833333, 35.02164008333333], [32.5108035, 35.02045192307692], [32.511280166666666, 35.01910566666667], [32.51188715, 35.0180358], [32.51250347368421, 35.0171572631579], [32.51318756521739, 35.017025347826085], [32.51392023076923, 35.016963076923076], [32.51476676923077, 35.01607546153846], [32.516021464285714, 35.01577553571428], [32.51687552631579, 35.01468457894737], [32.51948457142857, 35.01457057142857]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_293a536102ae916017d4d5ba33c5e4a6);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Add markers based on the height. If height is less than 100, add blue markers, otherwise red markers.

# %%
def track(row):
    loc = tuple(row[['lat', 'lng']])
    marker = folium.CircleMarker(location=loc,
                                color='blue' if row['height'] < 100 else 'red',
                                popup=row.name.strftime('%H:%m'))
    marker.add_to(m)

# %%
m = folium.Map(location=center, zoom_start=15)

min_df.apply(track, axis=1)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae1a5b149847f59a73e8c8cfb6e27c70 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae1a5b149847f59a73e8c8cfb6e27c70&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ae1a5b149847f59a73e8c8cfb6e27c70 = L.map(
#                 &quot;map_ae1a5b149847f59a73e8c8cfb6e27c70&quot;,
#                 {
#                     center: [32.51219109324327, 35.015832294594645],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a13c1aa6ac9fc09b16f98133b8dc73dd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ae1a5b149847f59a73e8c8cfb6e27c70);
#
#
#             var circle_marker_5eacb4f6ee27d333e362c6f316864373 = L.circleMarker(
#                 [32.51948457142857, 35.01457057142857],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ae1a5b149847f59a73e8c8cfb6e27c70);
#
#
#         var popup_7a61b4c2b9b162e1e60a2043293ab05d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8a0b5fd01d42df23ae1960994c4fad92 = $(`&lt;div id=&quot;html_8a0b5fd01d42df23ae1960994c4fad92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;03:08&lt;/div&gt;`)[0];
#             popup_7a61b4c2b9b162e1e60a2043293ab05d.setContent(html_8a0b5fd01d42df23ae1960994c4fad92);
#
#
#         circle_marker_5eacb4f6ee27d333e362c6f316864373.bindPopup(popup_7a61b4c2b9b162e1e60a2043293ab05d)
#         ;
#
#
#
#
#             var circle_marker_7a6bd8ff07dcfe25c7df880764249089 = L.circleMarker(
#                 [32.51897133333333, 35.01431633333333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ae1a5b149847f59a73e8c8cfb6e27c70);
#
#
#         var popup_b4836cb20642963e05c1e96332654f7f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3507a882c3446bdb9b3157c17893443f = $(`&lt;div id=&quot;html_3507a882c3446bdb9b3157c17893443f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;03:08&lt;/div&gt;`)[0];
#             popup_b4836cb20642963e05c1e96332654f7f.setContent(html_3507a882c3446bdb9b3157c17893443f);
#
#
#         circle_marker_7a6bd8ff07dcfe25c7df880764249089.bindPopup(popup_b4836cb20642963e05c1e96332654f7f)
#         ;
#
#
#
#
#             var circle_marker_5ffa01e8edecab8907adf47972c1d3f2 = L.circleMarker(
#                 [32.517257826086954, 35.0140552173913],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ae1a5b149847f59a73e8c8cfb6e27c70);
#
#
#         var popup_fcf7d7a3708bfcc06d4bfd08cc331100 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d0d690456abbcadb522dccf925875c38 = $(`&lt;div id=&quot;html_d0d690456abbcadb522dccf925875c38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;03:08&lt;/div&gt;`)[0];
#             popup_fcf7d7a3708bfcc06d4bfd08cc331100.setContent(html_d0d690456abbcadb522dccf925875c38);
#
#
#         circle_marker_5ffa01e8edecab8907adf47972c1d3f2.bindPopup(popup_fcf7d7a3708bfcc06d4bfd08cc331100)
#         ;
#
#
#
#
#             var circle_marker_b9e1d6f2f83cdbf0ac7d914bf78bc646 = L.circleMarker(
#                 [32.5162645, 35.01386383333333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot
